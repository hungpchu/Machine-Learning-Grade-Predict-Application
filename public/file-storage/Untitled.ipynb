# %%
import pandas as pd
def loadGrade():
    csv_path = "grade.csv"
    return pd.read_csv(csv_path)

# %%
grade = loadGrade()
grade.tail()
# Out:
#                Student       ID  SIS User ID   SIS Login ID  \
# 2        Matous Adamec  57014.0   50018756.0       madamec2
# 3     Abdullah Al Awfi   4861.0    8558403.0       aalawfi2
# 4   Jassim Alghushayan  37490.0   67513970.0  jalghushayan2
# 5          Mohamed Aly  68921.0   35801969.0          maly2
# 6  Tresor Paulin Anago  25605.0   45962788.0        tanago2
#
#                                           Section  Homework 1 (104496)  \
# 2  INTR DISCRETE STRUCT csce2355 SEC 150 FALL 2017                 98.0
# 3  INTR DISCRETE STRUCT csce2355 SEC 150 FALL 2017                 55.0
# 4  INTR DISCRETE STRUCT csce2355 SEC 150 FALL 2017                 83.0
# 5  INTR DISCRETE STRUCT csce2355 SEC 150 FALL 2017                110.0
# 6  INTR DISCRETE STRUCT csce2355 SEC 150 FALL 2017                 91.0
#
#    Homework 2 (104497)  \
# 2                101.0
# 3                  0.0
# 4                100.0
# 5                106.0
# 6                 87.0
#
#    Homework 3 (Formulas of problem are updated on October 2, 2017) (104498)  \
# 2                                              106.5
# 3                                                NaN
# 4                                              106.0
# 5                                              105.5
# 6                                              113.0
#
#    Homework 4 (104499)  Quiz 1 (133813)     ...     Midterm (151992)  \
# 2                  0.0              9.5     ...                 35.0
# 3                  0.0              7.0     ...                  0.0
# 4                  0.0              7.0     ...                 19.0
# 5                  0.0             10.0     ...                 32.0
# 6                  0.0              9.0     ...                 27.5
#
#    Quiz 5 (154249)  Assignments Current Points  Assignments Final Points  \
# 2              8.0                         387                       387
# 3              0.0                          62                        62
# 4              0.0                         335                       335
# 5              8.0                         398                       398
# 6              0.0                         345                       345
#
#    Assignments Current Score  Assignments Final Score Current Points  \
# 2                     100.52                    79.63            387
# 3                      21.75                    12.76             62
# 4                      86.79                    68.93            335
# 5                     103.38                    81.89            398
# 6                      89.61                    70.99            345
#
#   Final Points Current Score Final Score
# 2          387        100.52       79.63
# 3           62         21.75       12.76
# 4          335         86.79       68.93
# 5          398        103.38       81.89
# 6          345         89.61       70.99
#
# [5 rows x 24 columns]

# %%
grade.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 24 columns):
# Student                                                                     6 non-null object
# ID                                                                          5 non-null float64
# SIS User ID                                                                 5 non-null float64
# SIS Login ID                                                                5 non-null object
# Section                                                                     5 non-null object
# Homework 1 (104496)                                                         6 non-null float64
# Homework 2 (104497)                                                         6 non-null float64
# Homework 3 (Formulas of problem are updated on October 2, 2017) (104498)    5 non-null float64
# Homework 4 (104499)                                                         6 non-null float64
# Quiz 1 (133813)                                                             6 non-null float64
# Late Pass (138538)                                                          3 non-null object
# Quiz 2 (140201)                                                             6 non-null float64
# Quiz 3 (144955)                                                             6 non-null float64
# Quiz 4 (148638)                                                             6 non-null float64
# Midterm (151992)                                                            6 non-null float64
# Quiz 5 (154249)                                                             6 non-null float64
# Assignments Current Points                                                  6 non-null object
# Assignments Final Points                                                    6 non-null object
# Assignments Current Score                                                   6 non-null object
# Assignments Final Score                                                     6 non-null object
# Current Points                                                              6 non-null object
# Final Points                                                                6 non-null object
# Current Score                                                               6 non-null object
# Final Score                                                                 6 non-null object
# dtypes: float64(12), object(12)
# memory usage: 1.4+ KB

# %%
grade['Final Score'].value_counts()
# Out:
# (read only)    1
# 81.89          1
# 68.93          1
# 70.99          1
# 79.63          1
# 12.76          1
# Name: Final Score, dtype: int64

# %%
grade.describe()
# Out:
#                  ID   SIS User ID  Homework 1 (104496)  Homework 2 (104497)  \
# count      5.000000  5.000000e+00              6.00000             6.000000
# mean   38778.200000  4.157118e+07             89.50000            82.333333
# std    25331.314153  2.171867e+07             19.17029            40.824829
# min     4861.000000  8.558403e+06             55.00000             0.000000
# 25%    25605.000000  3.580197e+07             85.00000            90.250000
# 50%    37490.000000  4.596279e+07             94.50000           100.000000
# 75%    57014.000000  5.001876e+07             99.50000           100.750000
# max    68921.000000  6.751397e+07            110.00000           106.000000
#
#        Homework 3 (Formulas of problem are updated on October 2, 2017) (104498)  \
# count                                             5.0000
# mean                                            106.2000
# std                                               4.6179
# min                                             100.0000
# 25%                                             105.5000
# 50%                                             106.0000
# 75%                                             106.5000
# max                                             113.0000
#
#        Homework 4 (104499)  Quiz 1 (133813)  Quiz 2 (140201)  Quiz 3 (144955)  \
# count             6.000000         6.000000         6.000000         6.000000
# mean             16.666667         8.750000         5.666667         7.500000
# std              40.824829         1.405347         4.813176         3.834058
# min               0.000000         7.000000         0.000000         0.000000
# 25%               0.000000         7.500000         1.750000         7.500000
# 50%               0.000000         9.250000         6.250000         9.000000
# 75%               0.000000         9.875000        10.000000         9.750000
# max             100.000000        10.000000        10.000000        10.000000
#
#        Quiz 4 (148638)  Midterm (151992)  Quiz 5 (154249)
# count         6.000000          6.000000         6.000000
# mean          7.166667         24.750000         4.333333
# std           3.750556         13.534216         4.802777
# min           0.000000          0.000000         0.000000
# 25%           6.875000         21.125000         0.000000
# 50%           8.250000         29.750000         4.000000
# 75%           9.625000         34.250000         8.000000
# max          10.000000         35.000000        10.000000

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt
grade.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt
grade[“Total (105) ”].hist(bins=50, figsize=(10,5))
plt.show()
# Out:
#   File "<ipython-input-13-a41fab1f2736>", line 3
#     grade[“Total (105) ”].hist(bins=50, figsize=(10,5))
#                ^
# SyntaxError: invalid character in identifier

# %%
import sklearn
from sklearn.cross_validation import train_test_split
train_set, test_set = train_test_split(grade, test_size=0.2, random_state=42)
# Out:
# /home/han/.local/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
print(len(train_set), "train +", len(test_set), "test")
# Out:
# 5 train + 2 test
